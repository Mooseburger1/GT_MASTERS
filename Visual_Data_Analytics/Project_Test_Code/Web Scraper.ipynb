# %%
import pandas as pd
from bs4 import BeautifulSoup
from bs4.element import Comment
import requests
import re

# %%
html = requests.get('https://ww2db.com/country.php', verify = False).text
soup = BeautifulSoup(html, 'html.parser')
text = soup.get_text()
# Out:
# /home/scott/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
soup
# Out:
# <html>
# <head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script>(function(){function a(g,h,i){var j=new Date;j.setTime(j.getTime()+1e3*(60*(60*(24*i))));var k="expires="+j.toUTCString(),l=g+"="+h+";"+k+";path=/;";"undefined"!=typeof ezdomain&&(l+="domain="+ezdomain),document.cookie=l}var b=window.addEventListener?"addEventListener":"attachEvent",c=window[b],f="attachEvent"==b?"onmessage":"message";c(f,function(g){"undefined"!=typeof g.data.ezstatus&&(__ez.bit.AddAndFire(_ezaq.page_view_id,[new __ezDotData("dg",g.data.ezstatus)]),a("ezdg",g.data.ezstatus,730))})})();</script>
# ...

# %%
pd.read_html('https://ww2db.com/country.php')
# Out:
# [                       0   1
#  0  World War II Database NaN,
#      0                                                  1
#  0 NaN  Major Axis NationsGermanyItalyJapanMinor Axis ...
#  1 NaN  Major Allied NationsUnited KingdomUnited State...
#  2 NaN  Major Soviet NationRussiaMinor Soviet Nations ...
#  3 NaN  Neutral and Non-Belligerent NationsAfghanistan...,
#           0      1      2
#  0  Germany  Italy  Japan,
#                    0                   1                 2
#  0           Albania             Hungary  Marshall Islands
#  1           Austria     Italian Eritrea           Romania
#  2          Bulgaria  Italian Somaliland            Taiwan
#  3  Caroline Islands               Korea          Thailand
#  4    Czechoslovakia               Libya        Yugoslavia
#  5           Finland     Mariana Islands               NaN,
#                  0              1   2
#  0  United Kingdom  United States NaN,
# ...
