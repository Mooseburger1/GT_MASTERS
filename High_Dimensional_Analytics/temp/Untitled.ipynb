# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.linspace(0, 1, 1000)
Y_true = np.sin(2 * np.pi * X**3)**3

# %%
Y = np.sin(2 * np.pi * X**3)**3 + np.random.normal(0,0.1,X.shape)

# %%
plt.figure(figsize=(20,20))
plt.plot(X,Y_true, color='purple', lw=3)
plt.scatter(X,Y,edgecolor='k')
plt.plot(X, np.dot(H,B), color='green')
plt.show()

# %%
k = np.arange(1./7., 1.0, 1./7.)
k
# Out:
# array([0.14285714, 0.28571429, 0.42857143, 0.57142857, 0.71428571,
#        0.85714286, 1.        ])

# %%
h1 = np.ones(len(X))

# %%
h2 = X
h3 = X**2
h4 = X**3

# %%
h5 = X-k[0]
h5[h5 < 0] = 0

# %%
h6 = X-k[1]
h6[h6 < 0 ] = 0

# %%
h7 = X - k[2]
h7[h7 < 0] = 0

h8 = X - k[3]
h8[h8 < 0] = 0

h9 = X - k[4]
h9[h9 < 0] = 0

h10 = X-k[5]
h10[h10 < 0] = 0

# %%
H = np.array([h1, h2, h3, h4, h5, h6, h7, h8, h9, h10]).T

# %%
B = np.dot(np.linalg.inv(np.dot(H.T, H)) , np.dot(H.T,Y))

# %%
B
# Out:
# array([ -0.13589486,   6.27401971, -48.59266944,  37.94756819,
#          9.69665193,   4.35831063,   6.25931941, -12.96571682,
#        -16.30160403,  -2.40507734])

# %%
np.invert()
